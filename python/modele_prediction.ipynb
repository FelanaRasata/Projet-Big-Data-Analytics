# %% [markdown]
# # Analyse de données et modèle de prédiction

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when

# %% [markdown]
# ### Initialize Spark session

# %%
spark = SparkSession.builder \
    .appName("Vehicle Category Prediction") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
def print_df(df):
    print("Size", df.count())
    df.printSchema()
    df.show(5)

def load_data_in_csv_file(file_path):
    df = spark.read.options(delimiter=",", header=True, inferSchema=True).csv(file_path)

    # Display schema and first five rows of the DataFrame
    print("Schema and first rows in", file_path)
    print_df(df)
    
    return df

# %% [markdown]
# ### Load the dataset

# %%
# File path in Hadoop FS
hdfs_path = "hdfs:///tpa_groupe_14/data/fusion/fusion.csv"

# Load CSV data into a DataFrame
vehicles_df = load_data_in_csv_file(hdfs_path)
# Out:
# Schema and first rows in hdfs:///tpa_groupe_14/data/fusion/fusion.csv
# Size 100306
# root
#  |-- clients_ext.id: integer (nullable = true)
#  |-- clients_ext.age: integer (nullable = true)
#  |-- clients_ext.sexe: string (nullable = true)
#  |-- clients_ext.taux: integer (nullable = true)
#  |-- clients_ext.situationfamiliale: string (nullable = true)
#  |-- clients_ext.nbenfantsacharge: integer (nullable = true)
#  |-- clients_ext.deuxiemevoiture: boolean (nullable = true)
#  |-- clients_ext.immatriculation: string (nullable = true)
#  |-- immatriculation_ext.immatriculation: string (nullable = true)
#  |-- immatriculation_ext.marque: string (nullable = true)
#  |-- immatriculation_ext.nom: string (nullable = true)
#  |-- immatriculation_ext.puissance: integer (nullable = true)
#  |-- immatriculation_ext.longueur: string (nullable = true)
#  |-- immatriculation_ext.nbplaces: integer (nullable = true)
#  |-- immatriculation_ext.nbportes: integer (nullable = true)
#  |-- immatriculation_ext.couleur: string (nullable = true)
#  |-- immatriculation_ext.occasion: boolean (nullable = true)
#  |-- immatriculation_ext.prix: integer (nullable = true)
#  |-- catalogue_co2_ext.marque: string (nullable = true)
#  |-- catalogue_co2_ext.rejetco2: double (nullable = true)
#  |-- immatriculation_ext.cluster: integer (nullable = true)
#  |-- immatriculation_ext.categorie: string (nullable = true)
#
# +--------------+---------------+----------------+----------------+------------------------------+----------------------------+---------------------------+---------------------------+-----------------------------------+--------------------------+-----------------------+-----------------------------+----------------------------+----------------------------+----------------------------+---------------------------+----------------------------+------------------------+------------------------+--------------------------+---------------------------+-----------------------------+
# |clients_ext.id|clients_ext.age|clients_ext.sexe|clients_ext.taux|clients_ext.situationfamiliale|clients_ext.nbenfantsacharge|clients_ext.deuxiemevoiture|clients_ext.immatriculation|immatriculation_ext.immatriculation|immatriculation_ext.marque|immatriculation_ext.nom|immatriculation_ext.puissance|immatriculation_ext.longueur|immatriculation_ext.nbplaces|immatriculation_ext.nbportes|immatriculation_ext.couleur|immatriculation_ext.occasion|immatriculation_ext.prix|catalogue_co2_ext.marque|catalogue_co2_ext.rejetco2|immatriculation_ext.cluster|immatriculation_ext.categorie|
# +--------------+---------------+----------------+----------------+------------------------------+----------------------------+---------------------------+---------------------------+-----------------------------------+--------------------------+-----------------------+-----------------------------+----------------------------+----------------------------+----------------------------+---------------------------+----------------------------+------------------------+------------------------+--------------------------+---------------------------+-----------------------------+
# |            10|             79|               M|             153|                     En Couple|                           0|                      false|                 3042 ZQ 97|                         3042 ZQ 97|                      Seat|             Toledo 1.6|                          102|                      longue|                           5|                           5|                      rouge|                       false|                   18880|                    Seat|                     152.0|                          3|                     Sportive|
# |            11|             45|               M|             194|                     En Couple|                           1|                      false|                 3571 II 57|                         3571 II 57|                      Fiat|              Croma 2.2|                          147|                      longue|                           5|                           5|                       noir|                        true|                   17346|                    Fiat|                     152.0|                          3|                     Sportive|
# |            13|             53|               M|             237|                     En Couple|                           1|                      false|                 7885 CD 50|                         7885 CD 50|                     Volvo|                 S80 T6|                          272|                 très longue|                           5|                           5|                      blanc|                       false|                   50500|                   Volvo|                      42.0|                          0|                     Citadine|
# |            13|             53|               M|             237|                     En Couple|                           1|                      false|                 7885 CD 50|                         7885 CD 50|                   Renault|            Laguna 2.0T|                          170|                      longue|                           5|                           5|                      rouge|                        true|                   19110|                 Renault|                       0.0|                          0|                     Citadine|
# |            27|             75|               M|            1186|                     En Couple|                           3|                      false|                   45 ZQ 63|                           45 ZQ 63|                  Mercedes|                   S500|                          306|                 très longue|                           5|                           5|                      blanc|                       false|                  101300|                Mercedes|                     187.0|                          3|                     Sportive|
# +--------------+---------------+----------------+----------------+------------------------------+----------------------------+---------------------------+---------------------------+-----------------------------------+--------------------------+-----------------------+-----------------------------+----------------------------+----------------------------+----------------------------+---------------------------+----------------------------+------------------------+------------------------+--------------------------+---------------------------+-----------------------------+
# only showing top 5 rows

# %% [markdown]
# ### Data formatting

# %%
columns_to_drop = ["immatriculation_ext.immatriculation", "immatriculation_ext.marque", "immatriculation_ext.nom",
                   "immatriculation_ext.puissance", "immatriculation_ext.longueur", "immatriculation_ext.nbplaces",
                   "immatriculation_ext.nbportes", "immatriculation_ext.couleur", "immatriculation_ext.occasion",
                   "immatriculation_ext.prix", "immatriculation_ext.cluster", "catalogue_co2_ext.rejetco2",
                   "catalogue_co2_ext.marque", "clients_ext.immatriculation"]
vehicles_df = vehicles_df.drop(*columns_to_drop)

column_names = vehicles_df.schema.names

for column_name in column_names:
    vehicles_df = vehicles_df.withColumnRenamed(column_name, column_name.replace(".", "_"))

vehicles_df = vehicles_df.withColumn(
    "clients_ext_situationfamiliale", 
    when(col("clients_ext_situationfamiliale")=='Seul', "CELIBATAIRE") \
    .when(col("clients_ext_situationfamiliale")=='Seule', "CELIBATAIRE") \
    .when(col("clients_ext_situationfamiliale")=='Célibataire', "CELIBATAIRE") \
    .when(col("clients_ext_situationfamiliale")=='En Couple', "EN_COUPLE") \
    .when(col("clients_ext_situationfamiliale")=='Marié(e)', "MARIE") \
    .when(col("clients_ext_situationfamiliale")=='Divorcée', "DIVORCE") \
    .otherwise("*")
)

vehicles_df = vehicles_df.withColumn(
    "clients_ext_sexe", 
    when(col("clients_ext_sexe") == 'Homme', "M") \
    .when(col("clients_ext_sexe") == 'Masculin', "M") \
    .when(col("clients_ext_sexe") == 'M', "M") \
    .when(col("clients_ext_sexe") == 'Femme', "F") \
    .when(col("clients_ext_sexe") == 'Féminin', "F") \
    .when(col("clients_ext_sexe") == 'F', "F") \
    .otherwise("*")
)

# Replace negative values with zero
vehicles_df = vehicles_df.withColumn("clients_ext_deuxiemevoiture", when(col("clients_ext_deuxiemevoiture") == True, 1).otherwise(0))
vehicles_df = vehicles_df.withColumn("clients_ext_age", when(col("clients_ext_age") < 0, 0).otherwise(col("clients_ext_age")))
vehicles_df = vehicles_df.withColumn("clients_ext_taux", when(col("clients_ext_taux") < 0, 0).otherwise(col("clients_ext_taux")))
vehicles_df = vehicles_df.withColumn("clients_ext_nbenfantsacharge", when(col("clients_ext_nbenfantsacharge") < 0, 0).otherwise(col("clients_ext_nbenfantsacharge")))

# Print the schema to verify data types
print_df(vehicles_df)
# Out:
# Size 100306
# root
#  |-- clients_ext_id: integer (nullable = true)
#  |-- clients_ext_age: integer (nullable = true)
#  |-- clients_ext_sexe: string (nullable = false)
#  |-- clients_ext_taux: integer (nullable = true)
#  |-- clients_ext_situationfamiliale: string (nullable = false)
#  |-- clients_ext_nbenfantsacharge: integer (nullable = true)
#  |-- clients_ext_deuxiemevoiture: integer (nullable = false)
#  |-- immatriculation_ext_categorie: string (nullable = true)
#
# +--------------+---------------+----------------+----------------+------------------------------+----------------------------+---------------------------+-----------------------------+
# |clients_ext_id|clients_ext_age|clients_ext_sexe|clients_ext_taux|clients_ext_situationfamiliale|clients_ext_nbenfantsacharge|clients_ext_deuxiemevoiture|immatriculation_ext_categorie|
# +--------------+---------------+----------------+----------------+------------------------------+----------------------------+---------------------------+-----------------------------+
# |            10|             79|               M|             153|                     EN_COUPLE|                           0|                          0|                     Sportive|
# |            11|             45|               M|             194|                     EN_COUPLE|                           1|                          0|                     Sportive|
# |            13|             53|               M|             237|                     EN_COUPLE|                           1|                          0|                     Citadine|
# |            13|             53|               M|             237|                     EN_COUPLE|                           1|                          0|                     Citadine|
# |            27|             75|               M|            1186|                     EN_COUPLE|                           3|                          0|                     Sportive|
# +--------------+---------------+----------------+----------------+------------------------------+----------------------------+---------------------------+-----------------------------+
# only showing top 5 rows

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import VectorAssembler, StringIndexer

# %% [markdown]
# ### Optional

# %%
# Optional: Sub-sample the DataFrame
vehicles_df = vehicles_df.sample(withReplacement=False, fraction=0.3, seed=42)

# %%
# Prepare features
indexers = [
    StringIndexer(inputCol=column, outputCol=column+"_index").fit(vehicles_df)
    for column in ["clients_ext_sexe", "clients_ext_situationfamiliale", "immatriculation_ext_categorie"]
]

assembler = VectorAssembler(
    inputCols=[
        "clients_ext_age", "clients_ext_taux", "clients_ext_nbenfantsacharge", "clients_ext_deuxiemevoiture",
        "clients_ext_sexe_index", "clients_ext_situationfamiliale_index"
    ],
    outputCol="features"
)

# Split the DataFrame into training and test sets (80% training, 20% test)
train_df, test_df = vehicles_df.randomSplit([0.8, 0.2], seed=42)

pipeline = Pipeline(stages=indexers + [assembler])
pipeline_model = pipeline.fit(train_df)

train_df = pipeline_model.transform(train_df)
test_df = pipeline_model.transform(test_df)

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

# %%
# Evaluation function
def evaluate_classifier(classifier, param_grid, train_df, test_df):
    evaluator = MulticlassClassificationEvaluator(labelCol="immatriculation_ext_categorie_index", predictionCol="prediction", metricName="accuracy")
    
    # Create the cross-validator
    cross_validator = CrossValidator(
        estimator=classifier,
        estimatorParamMaps=param_grid,
        evaluator=evaluator,
        numFolds=3, 
        seed=42
    )
    
    # Train the model with the best hyperparameters
    cv_model = cross_validator.fit(train_df)
    
    # Make predictions on the test data
    predictions = cv_model.transform(test_df)
    
    # Evaluate the model
    accuracy = evaluator.evaluate(predictions)
    
    return cv_model, accuracy

# %%
from pyspark.ml.classification import (
    DecisionTreeClassifier, RandomForestClassifier, GBTClassifier, 
    LinearSVC, LogisticRegression, MultilayerPerceptronClassifier, NaiveBayes, OneVsRest
)

# %% [markdown]
# 1. Random Forest

# %%
rf = RandomForestClassifier(labelCol="immatriculation_ext_categorie_index", featuresCol="features")

# Define the hyperparameter grid
rf_param_grid = ParamGridBuilder() \
    .addGrid(rf.numTrees, [10, 20]) \
    .addGrid(rf.maxDepth, [5, 10]) \
    .build()

rf_model, rf_accuracy = evaluate_classifier(
    classifier=rf,
    param_grid=rf_param_grid,
    train_df=train_df,
    test_df=test_df
)

print("RandomForestClassifier Accuracy = {:.2f}".format(rf_accuracy))
# Out:
# 24/05/29 14:03:36 WARN DAGScheduler: Broadcasting large task binary with size 1018.5 KiB
# 24/05/29 14:03:46 WARN DAGScheduler: Broadcasting large task binary with size 1198.7 KiB
# 24/05/29 14:03:48 WARN DAGScheduler: Broadcasting large task binary with size 1856.0 KiB
# 24/05/29 14:03:49 WARN DAGScheduler: Broadcasting large task binary with size 1063.4 KiB
# 24/05/29 14:03:59 WARN DAGScheduler: Broadcasting large task binary with size 1030.6 KiB
# 24/05/29 14:04:08 WARN DAGScheduler: Broadcasting large task binary with size 1236.5 KiB
# 24/05/29 14:04:09 WARN DAGScheduler: Broadcasting large task binary with size 1906.2 KiB
# 24/05/29 14:04:10 WARN DAGScheduler: Broadcasting large task binary with size 1095.7 KiB
# 24/05/29 14:04:19 WARN DAGScheduler: Broadcasting large task binary with size 1079.2 KiB
# 24/05/29 14:04:28 WARN DAGScheduler: Broadcasting large task binary with size 1301.0 KiB
# 24/05/29 14:04:29 WARN DAGScheduler: Broadcasting large task binary with size 2025.8 KiB
# 24/05/29 14:04:31 WARN DAGScheduler: Broadcasting large task binary with size 1179.5 KiB
# 24/05/29 14:04:40 WARN DAGScheduler: Broadcasting large task binary with size 1318.3 KiB
# 24/05/29 14:04:41 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 24/05/29 14:04:43 WARN DAGScheduler: Broadcasting large task binary with size 1109.2 KiB
# [Stage 317:============================>                            (1 + 1) / 2]
# RandomForestClassifier Accuracy = 0.72

# %% [markdown]
# 2. Decision Tree

# %%
dt = DecisionTreeClassifier(labelCol="immatriculation_ext_categorie_index", featuresCol="features")

dt_param_grid = ParamGridBuilder()\
    .addGrid(dt.maxDepth, [5, 10])\
    .addGrid(dt.impurity, ["gini", "entropy"])\
    .build()

dt_model, dt_accuracy = evaluate_classifier(
    classifier=dt,
    param_grid=dt_param_grid,
    train_df=train_df,
    test_df=test_df
)

print("DecisionTreeClassifier Accuracy = {:.2f}".format(dt_accuracy))
# Out:
# DecisionTreeClassifier Accuracy = 0.72

# %% [markdown]
# 3. Gradient Boosted Trees

# %%
gbt = GBTClassifier(labelCol="immatriculation_ext_categorie_index", featuresCol="features")
ovr = OneVsRest(classifier=gbt, labelCol="immatriculation_ext_categorie_index", featuresCol="features")

gbt_param_grid = ParamGridBuilder()\
    .addGrid(gbt.maxIter, [10, 20])\
    .addGrid(gbt.maxDepth, [5, 10])\
    .build()

gbt_model, gbt_accuracy = evaluate_classifier(
    classifier=ovr,
    param_grid=gbt_param_grid,
    train_df=train_df,
    test_df=test_df
)

print("GBTClassifier Accuracy = {:.2f}".format(gbt_accuracy))
# Out:
# 24/05/29 14:07:45 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/05/29 14:08:01 WARN DAGScheduler: Broadcasting large task binary with size 1011.9 KiB
# 24/05/29 14:08:01 WARN DAGScheduler: Broadcasting large task binary with size 1058.0 KiB
# 24/05/29 14:08:01 WARN DAGScheduler: Broadcasting large task binary with size 1054.4 KiB
# 24/05/29 14:08:01 WARN DAGScheduler: Broadcasting large task binary with size 1054.9 KiB
# 24/05/29 14:08:01 WARN DAGScheduler: Broadcasting large task binary with size 1055.4 KiB
# 24/05/29 14:08:01 WARN DAGScheduler: Broadcasting large task binary with size 1056.6 KiB
# 24/05/29 14:08:01 WARN DAGScheduler: Broadcasting large task binary with size 1059.1 KiB
# 24/05/29 14:08:01 WARN DAGScheduler: Broadcasting large task binary with size 1063.5 KiB
# 24/05/29 14:08:02 WARN DAGScheduler: Broadcasting large task binary with size 1072.1 KiB
# 24/05/29 14:08:02 WARN DAGScheduler: Broadcasting large task binary with size 1089.0 KiB
# 24/05/29 14:08:02 WARN DAGScheduler: Broadcasting large task binary with size 1115.4 KiB
# 24/05/29 14:08:02 WARN DAGScheduler: Broadcasting large task binary with size 1156.6 KiB
# 24/05/29 14:08:34 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 24/05/29 14:09:26 WARN DAGScheduler: Broadcasting large task binary with size 1011.9 KiB
# 24/05/29 14:09:26 WARN DAGScheduler: Broadcasting large task binary with size 1058.0 KiB
# 24/05/29 14:09:26 WARN DAGScheduler: Broadcasting large task binary with size 1054.4 KiB
# 24/05/29 14:09:26 WARN DAGScheduler: Broadcasting large task binary with size 1054.9 KiB
# 24/05/29 14:09:27 WARN DAGScheduler: Broadcasting large task binary with size 1055.4 KiB
# 24/05/29 14:09:27 WARN DAGScheduler: Broadcasting large task binary with size 1056.6 KiB
# 24/05/29 14:09:27 WARN DAGScheduler: Broadcasting large task binary with size 1059.1 KiB
# 24/05/29 14:09:27 WARN DAGScheduler: Broadcasting large task binary with size 1063.5 KiB
# 24/05/29 14:09:27 WARN DAGScheduler: Broadcasting large task binary with size 1072.1 KiB
# 24/05/29 14:09:27 WARN DAGScheduler: Broadcasting large task binary with size 1089.0 KiB
# 24/05/29 14:09:27 WARN DAGScheduler: Broadcasting large task binary with size 1115.4 KiB
# 24/05/29 14:09:28 WARN DAGScheduler: Broadcasting large task binary with size 1156.6 KiB
# 24/05/29 14:09:28 WARN DAGScheduler: Broadcasting large task binary with size 1152.6 KiB
# 24/05/29 14:09:28 WARN DAGScheduler: Broadcasting large task binary with size 1153.1 KiB
# 24/05/29 14:09:28 WARN DAGScheduler: Broadcasting large task binary with size 1153.6 KiB
# 24/05/29 14:09:28 WARN DAGScheduler: Broadcasting large task binary with size 1154.8 KiB
# 24/05/29 14:09:28 WARN DAGScheduler: Broadcasting large task binary with size 1157.3 KiB
# 24/05/29 14:09:28 WARN DAGScheduler: Broadcasting large task binary with size 1161.6 KiB
# 24/05/29 14:09:28 WARN DAGScheduler: Broadcasting large task binary with size 1170.2 KiB
# 24/05/29 14:09:29 WARN DAGScheduler: Broadcasting large task binary with size 1186.9 KiB
# 24/05/29 14:09:29 WARN DAGScheduler: Broadcasting large task binary with size 1216.0 KiB
# 24/05/29 14:09:29 WARN DAGScheduler: Broadcasting large task binary with size 1262.5 KiB
# 24/05/29 14:09:29 WARN DAGScheduler: Broadcasting large task binary with size 1258.5 KiB
# 24/05/29 14:09:29 WARN DAGScheduler: Broadcasting large task binary with size 1259.0 KiB
# 24/05/29 14:09:29 WARN DAGScheduler: Broadcasting large task binary with size 1259.6 KiB
# 24/05/29 14:09:29 WARN DAGScheduler: Broadcasting large task binary with size 1260.8 KiB
# 24/05/29 14:09:30 WARN DAGScheduler: Broadcasting large task binary with size 1263.3 KiB
# 24/05/29 14:09:30 WARN DAGScheduler: Broadcasting large task binary with size 1267.8 KiB
# 24/05/29 14:09:30 WARN DAGScheduler: Broadcasting large task binary with size 1276.3 KiB
# 24/05/29 14:09:30 WARN DAGScheduler: Broadcasting large task binary with size 1293.0 KiB
# 24/05/29 14:09:30 WARN DAGScheduler: Broadcasting large task binary with size 1321.6 KiB
# 24/05/29 14:09:30 WARN DAGScheduler: Broadcasting large task binary with size 1366.8 KiB
# 24/05/29 14:09:30 WARN DAGScheduler: Broadcasting large task binary with size 1363.6 KiB
# 24/05/29 14:09:30 WARN DAGScheduler: Broadcasting large task binary with size 1364.1 KiB
# 24/05/29 14:09:31 WARN DAGScheduler: Broadcasting large task binary with size 1364.7 KiB
# 24/05/29 14:09:31 WARN DAGScheduler: Broadcasting large task binary with size 1365.9 KiB
# 24/05/29 14:09:31 WARN DAGScheduler: Broadcasting large task binary with size 1368.4 KiB
# 24/05/29 14:09:31 WARN DAGScheduler: Broadcasting large task binary with size 1372.8 KiB
# 24/05/29 14:09:31 WARN DAGScheduler: Broadcasting large task binary with size 1381.6 KiB
# 24/05/29 14:09:31 WARN DAGScheduler: Broadcasting large task binary with size 1398.8 KiB
# 24/05/29 14:09:31 WARN DAGScheduler: Broadcasting large task binary with size 1428.5 KiB
# 24/05/29 14:09:31 WARN DAGScheduler: Broadcasting large task binary with size 1474.9 KiB
# 24/05/29 14:09:32 WARN DAGScheduler: Broadcasting large task binary with size 1470.5 KiB
# 24/05/29 14:09:32 WARN DAGScheduler: Broadcasting large task binary with size 1471.0 KiB
# 24/05/29 14:09:32 WARN DAGScheduler: Broadcasting large task binary with size 1471.5 KiB
# 24/05/29 14:09:32 WARN DAGScheduler: Broadcasting large task binary with size 1472.7 KiB
# 24/05/29 14:09:32 WARN DAGScheduler: Broadcasting large task binary with size 1475.2 KiB
# 24/05/29 14:09:32 WARN DAGScheduler: Broadcasting large task binary with size 1479.7 KiB
# 24/05/29 14:09:32 WARN DAGScheduler: Broadcasting large task binary with size 1488.2 KiB
# 24/05/29 14:09:33 WARN DAGScheduler: Broadcasting large task binary with size 1504.4 KiB
# 24/05/29 14:09:33 WARN DAGScheduler: Broadcasting large task binary with size 1533.5 KiB
# 24/05/29 14:09:33 WARN DAGScheduler: Broadcasting large task binary with size 1577.7 KiB
# 24/05/29 14:09:33 WARN DAGScheduler: Broadcasting large task binary with size 1574.1 KiB
# 24/05/29 14:09:33 WARN DAGScheduler: Broadcasting large task binary with size 1574.6 KiB
# 24/05/29 14:09:33 WARN DAGScheduler: Broadcasting large task binary with size 1575.1 KiB
# 24/05/29 14:09:33 WARN DAGScheduler: Broadcasting large task binary with size 1576.3 KiB
# 24/05/29 14:09:34 WARN DAGScheduler: Broadcasting large task binary with size 1578.8 KiB
# 24/05/29 14:09:34 WARN DAGScheduler: Broadcasting large task binary with size 1583.5 KiB
# 24/05/29 14:09:34 WARN DAGScheduler: Broadcasting large task binary with size 1591.9 KiB
# 24/05/29 14:09:34 WARN DAGScheduler: Broadcasting large task binary with size 1608.2 KiB
# 24/05/29 14:09:34 WARN DAGScheduler: Broadcasting large task binary with size 1635.8 KiB
# 24/05/29 14:09:35 WARN DAGScheduler: Broadcasting large task binary with size 1678.6 KiB
# 24/05/29 14:09:35 WARN DAGScheduler: Broadcasting large task binary with size 1675.0 KiB
# 24/05/29 14:09:35 WARN DAGScheduler: Broadcasting large task binary with size 1675.5 KiB
# 24/05/29 14:09:35 WARN DAGScheduler: Broadcasting large task binary with size 1676.0 KiB
# 24/05/29 14:09:35 WARN DAGScheduler: Broadcasting large task binary with size 1677.2 KiB
# 24/05/29 14:09:35 WARN DAGScheduler: Broadcasting large task binary with size 1679.8 KiB
# 24/05/29 14:09:35 WARN DAGScheduler: Broadcasting large task binary with size 1684.1 KiB
# 24/05/29 14:09:36 WARN DAGScheduler: Broadcasting large task binary with size 1692.6 KiB
# 24/05/29 14:09:36 WARN DAGScheduler: Broadcasting large task binary with size 1709.4 KiB
# 24/05/29 14:09:36 WARN DAGScheduler: Broadcasting large task binary with size 1738.7 KiB
# 24/05/29 14:09:36 WARN DAGScheduler: Broadcasting large task binary with size 1785.5 KiB
# 24/05/29 14:09:36 WARN DAGScheduler: Broadcasting large task binary with size 1783.4 KiB
# 24/05/29 14:09:36 WARN DAGScheduler: Broadcasting large task binary with size 1783.8 KiB
# 24/05/29 14:09:37 WARN DAGScheduler: Broadcasting large task binary with size 1784.4 KiB
# 24/05/29 14:09:37 WARN DAGScheduler: Broadcasting large task binary with size 1785.6 KiB
# 24/05/29 14:09:37 WARN DAGScheduler: Broadcasting large task binary with size 1788.1 KiB
# 24/05/29 14:09:37 WARN DAGScheduler: Broadcasting large task binary with size 1792.7 KiB
# 24/05/29 14:09:37 WARN DAGScheduler: Broadcasting large task binary with size 1801.1 KiB
# 24/05/29 14:09:37 WARN DAGScheduler: Broadcasting large task binary with size 1818.0 KiB
# 24/05/29 14:09:37 WARN DAGScheduler: Broadcasting large task binary with size 1846.3 KiB
# 24/05/29 14:09:38 WARN DAGScheduler: Broadcasting large task binary with size 1893.7 KiB
# 24/05/29 14:09:38 WARN DAGScheduler: Broadcasting large task binary with size 1890.5 KiB
# 24/05/29 14:09:38 WARN DAGScheduler: Broadcasting large task binary with size 1891.0 KiB
# 24/05/29 14:09:38 WARN DAGScheduler: Broadcasting large task binary with size 1891.6 KiB
# 24/05/29 14:09:38 WARN DAGScheduler: Broadcasting large task binary with size 1892.8 KiB
# 24/05/29 14:09:38 WARN DAGScheduler: Broadcasting large task binary with size 1895.2 KiB
# 24/05/29 14:09:39 WARN DAGScheduler: Broadcasting large task binary with size 1899.5 KiB
# 24/05/29 14:09:39 WARN DAGScheduler: Broadcasting large task binary with size 1908.0 KiB
# 24/05/29 14:09:39 WARN DAGScheduler: Broadcasting large task binary with size 1924.7 KiB
# 24/05/29 14:09:39 WARN DAGScheduler: Broadcasting large task binary with size 1953.3 KiB
# 24/05/29 14:09:39 WARN DAGScheduler: Broadcasting large task binary with size 1999.8 KiB
# 24/05/29 14:09:39 WARN DAGScheduler: Broadcasting large task binary with size 1997.0 KiB
# 24/05/29 14:09:39 WARN DAGScheduler: Broadcasting large task binary with size 1997.4 KiB
# 24/05/29 14:09:40 WARN DAGScheduler: Broadcasting large task binary with size 1998.0 KiB
# 24/05/29 14:09:40 WARN DAGScheduler: Broadcasting large task binary with size 1999.2 KiB
# 24/05/29 14:09:40 WARN DAGScheduler: Broadcasting large task binary with size 2001.7 KiB
# 24/05/29 14:09:40 WARN DAGScheduler: Broadcasting large task binary with size 2006.0 KiB
# 24/05/29 14:09:40 WARN DAGScheduler: Broadcasting large task binary with size 2014.5 KiB
# 24/05/29 14:09:40 WARN DAGScheduler: Broadcasting large task binary with size 2031.3 KiB
# 24/05/29 14:09:40 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 24/05/29 14:09:41 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:09:41 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:09:41 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:09:41 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:09:41 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:09:41 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:09:42 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:09:42 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:09:42 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:09:42 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:09:42 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 24/05/29 14:09:53 WARN DAGScheduler: Broadcasting large task binary with size 1034.2 KiB
# 24/05/29 14:09:53 WARN DAGScheduler: Broadcasting large task binary with size 1030.9 KiB
# 24/05/29 14:09:53 WARN DAGScheduler: Broadcasting large task binary with size 1031.3 KiB
# 24/05/29 14:09:54 WARN DAGScheduler: Broadcasting large task binary with size 1031.9 KiB
# 24/05/29 14:09:54 WARN DAGScheduler: Broadcasting large task binary with size 1033.1 KiB
# 24/05/29 14:09:54 WARN DAGScheduler: Broadcasting large task binary with size 1035.1 KiB
# 24/05/29 14:09:54 WARN DAGScheduler: Broadcasting large task binary with size 1039.1 KiB
# 24/05/29 14:09:54 WARN DAGScheduler: Broadcasting large task binary with size 1046.3 KiB
# 24/05/29 14:09:54 WARN DAGScheduler: Broadcasting large task binary with size 1059.4 KiB
# 24/05/29 14:09:54 WARN DAGScheduler: Broadcasting large task binary with size 1082.3 KiB
# 24/05/29 14:09:54 WARN DAGScheduler: Broadcasting large task binary with size 1119.3 KiB
# 24/05/29 14:09:54 WARN DAGScheduler: Broadcasting large task binary with size 1115.6 KiB
# 24/05/29 14:09:55 WARN DAGScheduler: Broadcasting large task binary with size 1116.1 KiB
# 24/05/29 14:09:55 WARN DAGScheduler: Broadcasting large task binary with size 1116.6 KiB
# 24/05/29 14:09:55 WARN DAGScheduler: Broadcasting large task binary with size 1117.8 KiB
# 24/05/29 14:09:55 WARN DAGScheduler: Broadcasting large task binary with size 1119.9 KiB
# 24/05/29 14:09:55 WARN DAGScheduler: Broadcasting large task binary with size 1123.8 KiB
# 24/05/29 14:09:55 WARN DAGScheduler: Broadcasting large task binary with size 1130.7 KiB
# 24/05/29 14:09:55 WARN DAGScheduler: Broadcasting large task binary with size 1143.9 KiB
# 24/05/29 14:09:55 WARN DAGScheduler: Broadcasting large task binary with size 1166.8 KiB
# 24/05/29 14:09:55 WARN DAGScheduler: Broadcasting large task binary with size 1204.3 KiB
# 24/05/29 14:09:56 WARN DAGScheduler: Broadcasting large task binary with size 1201.7 KiB
# 24/05/29 14:09:56 WARN DAGScheduler: Broadcasting large task binary with size 1202.2 KiB
# 24/05/29 14:09:56 WARN DAGScheduler: Broadcasting large task binary with size 1202.8 KiB
# 24/05/29 14:09:56 WARN DAGScheduler: Broadcasting large task binary with size 1203.9 KiB
# 24/05/29 14:09:56 WARN DAGScheduler: Broadcasting large task binary with size 1206.3 KiB
# 24/05/29 14:09:56 WARN DAGScheduler: Broadcasting large task binary with size 1210.3 KiB
# 24/05/29 14:09:56 WARN DAGScheduler: Broadcasting large task binary with size 1217.3 KiB
# 24/05/29 14:09:56 WARN DAGScheduler: Broadcasting large task binary with size 1230.6 KiB
# 24/05/29 14:09:57 WARN DAGScheduler: Broadcasting large task binary with size 1254.1 KiB
# 24/05/29 14:09:57 WARN DAGScheduler: Broadcasting large task binary with size 1291.2 KiB
# 24/05/29 14:09:57 WARN DAGScheduler: Broadcasting large task binary with size 1288.0 KiB
# 24/05/29 14:09:57 WARN DAGScheduler: Broadcasting large task binary with size 1288.5 KiB
# 24/05/29 14:09:57 WARN DAGScheduler: Broadcasting large task binary with size 1289.0 KiB
# 24/05/29 14:09:57 WARN DAGScheduler: Broadcasting large task binary with size 1290.2 KiB
# 24/05/29 14:09:57 WARN DAGScheduler: Broadcasting large task binary with size 1292.6 KiB
# 24/05/29 14:09:57 WARN DAGScheduler: Broadcasting large task binary with size 1297.1 KiB
# 24/05/29 14:09:58 WARN DAGScheduler: Broadcasting large task binary with size 1304.7 KiB
# 24/05/29 14:09:58 WARN DAGScheduler: Broadcasting large task binary with size 1318.7 KiB
# 24/05/29 14:09:58 WARN DAGScheduler: Broadcasting large task binary with size 1342.7 KiB
# 24/05/29 14:09:58 WARN DAGScheduler: Broadcasting large task binary with size 1380.1 KiB
# 24/05/29 14:09:58 WARN DAGScheduler: Broadcasting large task binary with size 1374.3 KiB
# 24/05/29 14:09:58 WARN DAGScheduler: Broadcasting large task binary with size 1374.8 KiB
# 24/05/29 14:09:58 WARN DAGScheduler: Broadcasting large task binary with size 1375.4 KiB
# 24/05/29 14:09:59 WARN DAGScheduler: Broadcasting large task binary with size 1376.5 KiB
# 24/05/29 14:09:59 WARN DAGScheduler: Broadcasting large task binary with size 1378.9 KiB
# 24/05/29 14:09:59 WARN DAGScheduler: Broadcasting large task binary with size 1383.2 KiB
# 24/05/29 14:09:59 WARN DAGScheduler: Broadcasting large task binary with size 1390.6 KiB
# 24/05/29 14:09:59 WARN DAGScheduler: Broadcasting large task binary with size 1404.2 KiB
# 24/05/29 14:09:59 WARN DAGScheduler: Broadcasting large task binary with size 1426.9 KiB
# 24/05/29 14:09:59 WARN DAGScheduler: Broadcasting large task binary with size 1463.0 KiB
# 24/05/29 14:09:59 WARN DAGScheduler: Broadcasting large task binary with size 1460.1 KiB
# 24/05/29 14:10:00 WARN DAGScheduler: Broadcasting large task binary with size 1460.6 KiB
# 24/05/29 14:10:00 WARN DAGScheduler: Broadcasting large task binary with size 1461.2 KiB
# 24/05/29 14:10:00 WARN DAGScheduler: Broadcasting large task binary with size 1462.3 KiB
# 24/05/29 14:10:00 WARN DAGScheduler: Broadcasting large task binary with size 1464.3 KiB
# 24/05/29 14:10:00 WARN DAGScheduler: Broadcasting large task binary with size 1468.1 KiB
# 24/05/29 14:10:00 WARN DAGScheduler: Broadcasting large task binary with size 1475.2 KiB
# 24/05/29 14:10:00 WARN DAGScheduler: Broadcasting large task binary with size 1488.8 KiB
# 24/05/29 14:10:00 WARN DAGScheduler: Broadcasting large task binary with size 1512.7 KiB
# 24/05/29 14:10:01 WARN DAGScheduler: Broadcasting large task binary with size 1553.3 KiB
# 24/05/29 14:10:01 WARN DAGScheduler: Broadcasting large task binary with size 1553.5 KiB
# 24/05/29 14:10:01 WARN DAGScheduler: Broadcasting large task binary with size 1554.0 KiB
# 24/05/29 14:10:01 WARN DAGScheduler: Broadcasting large task binary with size 1554.6 KiB
# 24/05/29 14:10:01 WARN DAGScheduler: Broadcasting large task binary with size 1555.7 KiB
# 24/05/29 14:10:01 WARN DAGScheduler: Broadcasting large task binary with size 1557.8 KiB
# 24/05/29 14:10:01 WARN DAGScheduler: Broadcasting large task binary with size 1561.7 KiB
# 24/05/29 14:10:02 WARN DAGScheduler: Broadcasting large task binary with size 1568.8 KiB
# 24/05/29 14:10:02 WARN DAGScheduler: Broadcasting large task binary with size 1582.4 KiB
# 24/05/29 14:10:02 WARN DAGScheduler: Broadcasting large task binary with size 1605.4 KiB
# 24/05/29 14:10:02 WARN DAGScheduler: Broadcasting large task binary with size 1642.3 KiB
# 24/05/29 14:10:02 WARN DAGScheduler: Broadcasting large task binary with size 1640.8 KiB
# 24/05/29 14:10:02 WARN DAGScheduler: Broadcasting large task binary with size 1641.2 KiB
# 24/05/29 14:10:02 WARN DAGScheduler: Broadcasting large task binary with size 1641.8 KiB
# 24/05/29 14:10:03 WARN DAGScheduler: Broadcasting large task binary with size 1643.0 KiB
# 24/05/29 14:10:03 WARN DAGScheduler: Broadcasting large task binary with size 1645.0 KiB
# 24/05/29 14:10:03 WARN DAGScheduler: Broadcasting large task binary with size 1648.8 KiB
# 24/05/29 14:10:03 WARN DAGScheduler: Broadcasting large task binary with size 1656.0 KiB
# 24/05/29 14:10:03 WARN DAGScheduler: Broadcasting large task binary with size 1669.5 KiB
# 24/05/29 14:10:03 WARN DAGScheduler: Broadcasting large task binary with size 1694.3 KiB
# 24/05/29 14:10:03 WARN DAGScheduler: Broadcasting large task binary with size 1736.6 KiB
# 24/05/29 14:10:04 WARN DAGScheduler: Broadcasting large task binary with size 1735.8 KiB
# 24/05/29 14:10:04 WARN DAGScheduler: Broadcasting large task binary with size 1736.3 KiB
# 24/05/29 14:10:04 WARN DAGScheduler: Broadcasting large task binary with size 1736.9 KiB
# 24/05/29 14:10:04 WARN DAGScheduler: Broadcasting large task binary with size 1738.0 KiB
# 24/05/29 14:10:04 WARN DAGScheduler: Broadcasting large task binary with size 1740.0 KiB
# 24/05/29 14:10:04 WARN DAGScheduler: Broadcasting large task binary with size 1743.8 KiB
# 24/05/29 14:10:04 WARN DAGScheduler: Broadcasting large task binary with size 1751.0 KiB
# 24/05/29 14:10:05 WARN DAGScheduler: Broadcasting large task binary with size 1764.6 KiB
# 24/05/29 14:10:05 WARN DAGScheduler: Broadcasting large task binary with size 1788.7 KiB
# 24/05/29 14:10:05 WARN DAGScheduler: Broadcasting large task binary with size 1829.9 KiB
# 24/05/29 14:10:18 WARN DAGScheduler: Broadcasting large task binary with size 1023.2 KiB
# 24/05/29 14:10:18 WARN DAGScheduler: Broadcasting large task binary with size 1016.5 KiB
# 24/05/29 14:10:19 WARN DAGScheduler: Broadcasting large task binary with size 1017.0 KiB
# 24/05/29 14:10:19 WARN DAGScheduler: Broadcasting large task binary with size 1017.6 KiB
# 24/05/29 14:10:19 WARN DAGScheduler: Broadcasting large task binary with size 1018.8 KiB
# 24/05/29 14:10:19 WARN DAGScheduler: Broadcasting large task binary with size 1020.8 KiB
# 24/05/29 14:10:19 WARN DAGScheduler: Broadcasting large task binary with size 1024.5 KiB
# 24/05/29 14:10:19 WARN DAGScheduler: Broadcasting large task binary with size 1031.1 KiB
# 24/05/29 14:10:19 WARN DAGScheduler: Broadcasting large task binary with size 1042.8 KiB
# 24/05/29 14:10:19 WARN DAGScheduler: Broadcasting large task binary with size 1062.1 KiB
# 24/05/29 14:10:19 WARN DAGScheduler: Broadcasting large task binary with size 1092.1 KiB
# 24/05/29 14:10:20 WARN DAGScheduler: Broadcasting large task binary with size 1087.3 KiB
# 24/05/29 14:10:20 WARN DAGScheduler: Broadcasting large task binary with size 1087.8 KiB
# 24/05/29 14:10:20 WARN DAGScheduler: Broadcasting large task binary with size 1088.4 KiB
# 24/05/29 14:10:20 WARN DAGScheduler: Broadcasting large task binary with size 1089.5 KiB
# 24/05/29 14:10:20 WARN DAGScheduler: Broadcasting large task binary with size 1091.6 KiB
# 24/05/29 14:10:20 WARN DAGScheduler: Broadcasting large task binary with size 1095.3 KiB
# 24/05/29 14:10:20 WARN DAGScheduler: Broadcasting large task binary with size 1101.9 KiB
# 24/05/29 14:10:20 WARN DAGScheduler: Broadcasting large task binary with size 1113.3 KiB
# 24/05/29 14:10:20 WARN DAGScheduler: Broadcasting large task binary with size 1132.3 KiB
# 24/05/29 14:10:21 WARN DAGScheduler: Broadcasting large task binary with size 1162.9 KiB
# 24/05/29 14:10:21 WARN DAGScheduler: Broadcasting large task binary with size 1159.0 KiB
# 24/05/29 14:10:21 WARN DAGScheduler: Broadcasting large task binary with size 1159.5 KiB
# 24/05/29 14:10:21 WARN DAGScheduler: Broadcasting large task binary with size 1160.1 KiB
# 24/05/29 14:10:21 WARN DAGScheduler: Broadcasting large task binary with size 1161.2 KiB
# 24/05/29 14:10:21 WARN DAGScheduler: Broadcasting large task binary with size 1163.3 KiB
# 24/05/29 14:10:21 WARN DAGScheduler: Broadcasting large task binary with size 1167.0 KiB
# 24/05/29 14:10:21 WARN DAGScheduler: Broadcasting large task binary with size 1173.6 KiB
# 24/05/29 14:10:22 WARN DAGScheduler: Broadcasting large task binary with size 1184.7 KiB
# 24/05/29 14:10:22 WARN DAGScheduler: Broadcasting large task binary with size 1203.0 KiB
# 24/05/29 14:10:22 WARN DAGScheduler: Broadcasting large task binary with size 1231.4 KiB
# 24/05/29 14:10:22 WARN DAGScheduler: Broadcasting large task binary with size 1227.2 KiB
# 24/05/29 14:10:22 WARN DAGScheduler: Broadcasting large task binary with size 1227.7 KiB
# 24/05/29 14:10:22 WARN DAGScheduler: Broadcasting large task binary with size 1228.3 KiB
# 24/05/29 14:10:22 WARN DAGScheduler: Broadcasting large task binary with size 1229.4 KiB
# 24/05/29 14:10:22 WARN DAGScheduler: Broadcasting large task binary with size 1231.7 KiB
# 24/05/29 14:10:22 WARN DAGScheduler: Broadcasting large task binary with size 1235.9 KiB
# 24/05/29 14:10:23 WARN DAGScheduler: Broadcasting large task binary with size 1243.0 KiB
# 24/05/29 14:10:23 WARN DAGScheduler: Broadcasting large task binary with size 1254.7 KiB
# 24/05/29 14:10:23 WARN DAGScheduler: Broadcasting large task binary with size 1273.5 KiB
# 24/05/29 14:10:23 WARN DAGScheduler: Broadcasting large task binary with size 1301.5 KiB
# 24/05/29 14:10:23 WARN DAGScheduler: Broadcasting large task binary with size 1295.2 KiB
# 24/05/29 14:10:23 WARN DAGScheduler: Broadcasting large task binary with size 1295.8 KiB
# 24/05/29 14:10:23 WARN DAGScheduler: Broadcasting large task binary with size 1296.3 KiB
# 24/05/29 14:10:23 WARN DAGScheduler: Broadcasting large task binary with size 1297.5 KiB
# 24/05/29 14:10:24 WARN DAGScheduler: Broadcasting large task binary with size 1299.8 KiB
# 24/05/29 14:10:24 WARN DAGScheduler: Broadcasting large task binary with size 1304.3 KiB
# 24/05/29 14:10:24 WARN DAGScheduler: Broadcasting large task binary with size 1311.7 KiB
# 24/05/29 14:10:24 WARN DAGScheduler: Broadcasting large task binary with size 1323.9 KiB
# 24/05/29 14:10:24 WARN DAGScheduler: Broadcasting large task binary with size 1343.4 KiB
# 24/05/29 14:10:24 WARN DAGScheduler: Broadcasting large task binary with size 1371.6 KiB
# 24/05/29 14:10:24 WARN DAGScheduler: Broadcasting large task binary with size 1364.6 KiB
# 24/05/29 14:10:24 WARN DAGScheduler: Broadcasting large task binary with size 1365.1 KiB
# 24/05/29 14:10:25 WARN DAGScheduler: Broadcasting large task binary with size 1365.7 KiB
# 24/05/29 14:10:25 WARN DAGScheduler: Broadcasting large task binary with size 1366.8 KiB
# 24/05/29 14:10:25 WARN DAGScheduler: Broadcasting large task binary with size 1369.1 KiB
# 24/05/29 14:10:25 WARN DAGScheduler: Broadcasting large task binary with size 1373.3 KiB
# 24/05/29 14:10:25 WARN DAGScheduler: Broadcasting large task binary with size 1380.3 KiB
# 24/05/29 14:10:25 WARN DAGScheduler: Broadcasting large task binary with size 1391.8 KiB
# 24/05/29 14:10:25 WARN DAGScheduler: Broadcasting large task binary with size 1410.7 KiB
# 24/05/29 14:10:25 WARN DAGScheduler: Broadcasting large task binary with size 1439.8 KiB
# 24/05/29 14:10:40 WARN DAGScheduler: Broadcasting large task binary with size 1005.0 KiB
# 24/05/29 14:10:40 WARN DAGScheduler: Broadcasting large task binary with size 1021.7 KiB
# 24/05/29 14:10:40 WARN DAGScheduler: Broadcasting large task binary with size 1049.2 KiB
# 24/05/29 14:10:40 WARN DAGScheduler: Broadcasting large task binary with size 1046.3 KiB
# 24/05/29 14:10:40 WARN DAGScheduler: Broadcasting large task binary with size 1046.9 KiB
# 24/05/29 14:10:40 WARN DAGScheduler: Broadcasting large task binary with size 1047.4 KiB
# 24/05/29 14:10:40 WARN DAGScheduler: Broadcasting large task binary with size 1048.6 KiB
# 24/05/29 14:10:40 WARN DAGScheduler: Broadcasting large task binary with size 1050.9 KiB
# 24/05/29 14:10:40 WARN DAGScheduler: Broadcasting large task binary with size 1054.4 KiB
# 24/05/29 14:10:40 WARN DAGScheduler: Broadcasting large task binary with size 1060.0 KiB
# 24/05/29 14:10:41 WARN DAGScheduler: Broadcasting large task binary with size 1070.5 KiB
# 24/05/29 14:10:41 WARN DAGScheduler: Broadcasting large task binary with size 1087.7 KiB
# 24/05/29 14:10:41 WARN DAGScheduler: Broadcasting large task binary with size 1115.8 KiB
# 24/05/29 14:10:41 WARN DAGScheduler: Broadcasting large task binary with size 1113.4 KiB
# 24/05/29 14:10:41 WARN DAGScheduler: Broadcasting large task binary with size 1113.9 KiB
# 24/05/29 14:10:41 WARN DAGScheduler: Broadcasting large task binary with size 1114.5 KiB
# 24/05/29 14:10:41 WARN DAGScheduler: Broadcasting large task binary with size 1115.7 KiB
# 24/05/29 14:10:41 WARN DAGScheduler: Broadcasting large task binary with size 1117.9 KiB
# 24/05/29 14:10:42 WARN DAGScheduler: Broadcasting large task binary with size 1121.1 KiB
# 24/05/29 14:10:42 WARN DAGScheduler: Broadcasting large task binary with size 1126.7 KiB
# 24/05/29 14:10:42 WARN DAGScheduler: Broadcasting large task binary with size 1137.0 KiB
# 24/05/29 14:10:42 WARN DAGScheduler: Broadcasting large task binary with size 1154.2 KiB
# 24/05/29 14:10:42 WARN DAGScheduler: Broadcasting large task binary with size 1182.4 KiB
# 24/05/29 14:10:42 WARN DAGScheduler: Broadcasting large task binary with size 1179.7 KiB
# 24/05/29 14:10:42 WARN DAGScheduler: Broadcasting large task binary with size 1180.2 KiB
# 24/05/29 14:10:42 WARN DAGScheduler: Broadcasting large task binary with size 1180.8 KiB
# 24/05/29 14:10:43 WARN DAGScheduler: Broadcasting large task binary with size 1182.0 KiB
# 24/05/29 14:10:43 WARN DAGScheduler: Broadcasting large task binary with size 1184.2 KiB
# 24/05/29 14:10:43 WARN DAGScheduler: Broadcasting large task binary with size 1187.7 KiB
# 24/05/29 14:10:43 WARN DAGScheduler: Broadcasting large task binary with size 1193.3 KiB
# 24/05/29 14:10:43 WARN DAGScheduler: Broadcasting large task binary with size 1203.8 KiB
# 24/05/29 14:10:43 WARN DAGScheduler: Broadcasting large task binary with size 1221.2 KiB
# 24/05/29 14:10:43 WARN DAGScheduler: Broadcasting large task binary with size 1248.6 KiB
# 24/05/29 14:10:43 WARN DAGScheduler: Broadcasting large task binary with size 1245.4 KiB
# 24/05/29 14:10:44 WARN DAGScheduler: Broadcasting large task binary with size 1246.0 KiB
# 24/05/29 14:10:44 WARN DAGScheduler: Broadcasting large task binary with size 1246.5 KiB
# 24/05/29 14:10:44 WARN DAGScheduler: Broadcasting large task binary with size 1247.7 KiB
# 24/05/29 14:10:44 WARN DAGScheduler: Broadcasting large task binary with size 1249.7 KiB
# 24/05/29 14:10:44 WARN DAGScheduler: Broadcasting large task binary with size 1253.1 KiB
# 24/05/29 14:10:44 WARN DAGScheduler: Broadcasting large task binary with size 1258.7 KiB
# 24/05/29 14:10:44 WARN DAGScheduler: Broadcasting large task binary with size 1269.4 KiB
# 24/05/29 14:10:44 WARN DAGScheduler: Broadcasting large task binary with size 1286.7 KiB
# 24/05/29 14:10:44 WARN DAGScheduler: Broadcasting large task binary with size 1313.0 KiB
# 24/05/29 14:10:45 WARN DAGScheduler: Broadcasting large task binary with size 1310.4 KiB
# 24/05/29 14:10:45 WARN DAGScheduler: Broadcasting large task binary with size 1310.9 KiB
# 24/05/29 14:10:45 WARN DAGScheduler: Broadcasting large task binary with size 1311.5 KiB
# 24/05/29 14:10:45 WARN DAGScheduler: Broadcasting large task binary with size 1312.7 KiB
# 24/05/29 14:10:45 WARN DAGScheduler: Broadcasting large task binary with size 1314.9 KiB
# 24/05/29 14:10:45 WARN DAGScheduler: Broadcasting large task binary with size 1318.3 KiB
# 24/05/29 14:10:45 WARN DAGScheduler: Broadcasting large task binary with size 1324.0 KiB
# 24/05/29 14:10:46 WARN DAGScheduler: Broadcasting large task binary with size 1334.5 KiB
# 24/05/29 14:10:46 WARN DAGScheduler: Broadcasting large task binary with size 1351.1 KiB
# 24/05/29 14:10:46 WARN DAGScheduler: Broadcasting large task binary with size 1376.3 KiB
# 24/05/29 14:10:47 WARN DAGScheduler: Broadcasting large task binary with size 6.3 MiB
# 24/05/29 14:11:23 WARN DAGScheduler: Broadcasting large task binary with size 1004.3 KiB
# 24/05/29 14:11:24 WARN DAGScheduler: Broadcasting large task binary with size 1052.2 KiB
# 24/05/29 14:11:24 WARN DAGScheduler: Broadcasting large task binary with size 1049.1 KiB
# 24/05/29 14:11:24 WARN DAGScheduler: Broadcasting large task binary with size 1049.6 KiB
# 24/05/29 14:11:24 WARN DAGScheduler: Broadcasting large task binary with size 1050.2 KiB
# 24/05/29 14:11:24 WARN DAGScheduler: Broadcasting large task binary with size 1051.4 KiB
# 24/05/29 14:11:24 WARN DAGScheduler: Broadcasting large task binary with size 1053.9 KiB
# 24/05/29 14:11:24 WARN DAGScheduler: Broadcasting large task binary with size 1058.5 KiB
# 24/05/29 14:11:25 WARN DAGScheduler: Broadcasting large task binary with size 1067.6 KiB
# 24/05/29 14:11:25 WARN DAGScheduler: Broadcasting large task binary with size 1084.9 KiB
# 24/05/29 14:11:25 WARN DAGScheduler: Broadcasting large task binary with size 1114.4 KiB
# 24/05/29 14:11:25 WARN DAGScheduler: Broadcasting large task binary with size 1162.7 KiB
# 24/05/29 14:11:34 WARN DAGScheduler: Broadcasting large task binary with size 1038.7 KiB
# 24/05/29 14:11:54 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 24/05/29 14:12:41 WARN DAGScheduler: Broadcasting large task binary with size 1004.3 KiB
# 24/05/29 14:12:42 WARN DAGScheduler: Broadcasting large task binary with size 1052.2 KiB
# 24/05/29 14:12:42 WARN DAGScheduler: Broadcasting large task binary with size 1049.1 KiB
# 24/05/29 14:12:42 WARN DAGScheduler: Broadcasting large task binary with size 1049.6 KiB
# 24/05/29 14:12:42 WARN DAGScheduler: Broadcasting large task binary with size 1050.2 KiB
# 24/05/29 14:12:42 WARN DAGScheduler: Broadcasting large task binary with size 1051.4 KiB
# 24/05/29 14:12:43 WARN DAGScheduler: Broadcasting large task binary with size 1053.9 KiB
# 24/05/29 14:12:43 WARN DAGScheduler: Broadcasting large task binary with size 1058.5 KiB
# 24/05/29 14:12:43 WARN DAGScheduler: Broadcasting large task binary with size 1067.6 KiB
# 24/05/29 14:12:43 WARN DAGScheduler: Broadcasting large task binary with size 1084.9 KiB
# 24/05/29 14:12:43 WARN DAGScheduler: Broadcasting large task binary with size 1114.4 KiB
# 24/05/29 14:12:43 WARN DAGScheduler: Broadcasting large task binary with size 1162.7 KiB
# 24/05/29 14:12:43 WARN DAGScheduler: Broadcasting large task binary with size 1158.1 KiB
# 24/05/29 14:12:43 WARN DAGScheduler: Broadcasting large task binary with size 1158.6 KiB
# 24/05/29 14:12:44 WARN DAGScheduler: Broadcasting large task binary with size 1159.2 KiB
# 24/05/29 14:12:44 WARN DAGScheduler: Broadcasting large task binary with size 1160.3 KiB
# 24/05/29 14:12:44 WARN DAGScheduler: Broadcasting large task binary with size 1162.8 KiB
# 24/05/29 14:12:44 WARN DAGScheduler: Broadcasting large task binary with size 1167.4 KiB
# 24/05/29 14:12:44 WARN DAGScheduler: Broadcasting large task binary with size 1176.1 KiB
# 24/05/29 14:12:44 WARN DAGScheduler: Broadcasting large task binary with size 1192.1 KiB
# 24/05/29 14:12:44 WARN DAGScheduler: Broadcasting large task binary with size 1218.5 KiB
# 24/05/29 14:12:44 WARN DAGScheduler: Broadcasting large task binary with size 1264.5 KiB
# 24/05/29 14:12:44 WARN DAGScheduler: Broadcasting large task binary with size 1263.2 KiB
# 24/05/29 14:12:45 WARN DAGScheduler: Broadcasting large task binary with size 1263.7 KiB
# 24/05/29 14:12:45 WARN DAGScheduler: Broadcasting large task binary with size 1264.3 KiB
# 24/05/29 14:12:45 WARN DAGScheduler: Broadcasting large task binary with size 1265.5 KiB
# 24/05/29 14:12:45 WARN DAGScheduler: Broadcasting large task binary with size 1268.0 KiB
# 24/05/29 14:12:45 WARN DAGScheduler: Broadcasting large task binary with size 1272.5 KiB
# 24/05/29 14:12:45 WARN DAGScheduler: Broadcasting large task binary with size 1281.2 KiB
# 24/05/29 14:12:45 WARN DAGScheduler: Broadcasting large task binary with size 1297.9 KiB
# 24/05/29 14:12:45 WARN DAGScheduler: Broadcasting large task binary with size 1326.7 KiB
# 24/05/29 14:12:46 WARN DAGScheduler: Broadcasting large task binary with size 1375.0 KiB
# 24/05/29 14:12:46 WARN DAGScheduler: Broadcasting large task binary with size 1371.7 KiB
# 24/05/29 14:12:46 WARN DAGScheduler: Broadcasting large task binary with size 1372.2 KiB
# 24/05/29 14:12:46 WARN DAGScheduler: Broadcasting large task binary with size 1372.8 KiB
# 24/05/29 14:12:46 WARN DAGScheduler: Broadcasting large task binary with size 1374.0 KiB
# 24/05/29 14:12:46 WARN DAGScheduler: Broadcasting large task binary with size 1376.5 KiB
# 24/05/29 14:12:46 WARN DAGScheduler: Broadcasting large task binary with size 1381.0 KiB
# 24/05/29 14:12:47 WARN DAGScheduler: Broadcasting large task binary with size 1389.7 KiB
# 24/05/29 14:12:47 WARN DAGScheduler: Broadcasting large task binary with size 1406.2 KiB
# 24/05/29 14:12:47 WARN DAGScheduler: Broadcasting large task binary with size 1433.5 KiB
# 24/05/29 14:12:47 WARN DAGScheduler: Broadcasting large task binary with size 1480.3 KiB
# 24/05/29 14:12:47 WARN DAGScheduler: Broadcasting large task binary with size 1477.6 KiB
# 24/05/29 14:12:47 WARN DAGScheduler: Broadcasting large task binary with size 1478.1 KiB
# 24/05/29 14:12:47 WARN DAGScheduler: Broadcasting large task binary with size 1478.7 KiB
# 24/05/29 14:12:48 WARN DAGScheduler: Broadcasting large task binary with size 1479.9 KiB
# 24/05/29 14:12:48 WARN DAGScheduler: Broadcasting large task binary with size 1482.4 KiB
# 24/05/29 14:12:48 WARN DAGScheduler: Broadcasting large task binary with size 1486.8 KiB
# 24/05/29 14:12:48 WARN DAGScheduler: Broadcasting large task binary with size 1495.6 KiB
# 24/05/29 14:12:48 WARN DAGScheduler: Broadcasting large task binary with size 1512.5 KiB
# 24/05/29 14:12:48 WARN DAGScheduler: Broadcasting large task binary with size 1541.6 KiB
# 24/05/29 14:12:48 WARN DAGScheduler: Broadcasting large task binary with size 1589.3 KiB
# 24/05/29 14:12:48 WARN DAGScheduler: Broadcasting large task binary with size 1587.2 KiB
# 24/05/29 14:12:49 WARN DAGScheduler: Broadcasting large task binary with size 1587.6 KiB
# 24/05/29 14:12:49 WARN DAGScheduler: Broadcasting large task binary with size 1588.3 KiB
# 24/05/29 14:12:49 WARN DAGScheduler: Broadcasting large task binary with size 1589.4 KiB
# 24/05/29 14:12:49 WARN DAGScheduler: Broadcasting large task binary with size 1591.9 KiB
# 24/05/29 14:12:49 WARN DAGScheduler: Broadcasting large task binary with size 1596.5 KiB
# 24/05/29 14:12:49 WARN DAGScheduler: Broadcasting large task binary with size 1605.2 KiB
# 24/05/29 14:12:49 WARN DAGScheduler: Broadcasting large task binary with size 1622.4 KiB
# 24/05/29 14:12:49 WARN DAGScheduler: Broadcasting large task binary with size 1652.1 KiB
# 24/05/29 14:12:50 WARN DAGScheduler: Broadcasting large task binary with size 1701.4 KiB
# 24/05/29 14:12:50 WARN DAGScheduler: Broadcasting large task binary with size 1701.1 KiB
# 24/05/29 14:12:50 WARN DAGScheduler: Broadcasting large task binary with size 1701.5 KiB
# 24/05/29 14:12:50 WARN DAGScheduler: Broadcasting large task binary with size 1702.2 KiB
# 24/05/29 14:12:50 WARN DAGScheduler: Broadcasting large task binary with size 1703.3 KiB
# 24/05/29 14:12:50 WARN DAGScheduler: Broadcasting large task binary with size 1705.8 KiB
# 24/05/29 14:12:51 WARN DAGScheduler: Broadcasting large task binary with size 1710.4 KiB
# 24/05/29 14:12:51 WARN DAGScheduler: Broadcasting large task binary with size 1719.1 KiB
# 24/05/29 14:12:51 WARN DAGScheduler: Broadcasting large task binary with size 1736.0 KiB
# 24/05/29 14:12:51 WARN DAGScheduler: Broadcasting large task binary with size 1764.7 KiB
# 24/05/29 14:12:51 WARN DAGScheduler: Broadcasting large task binary with size 1814.8 KiB
# 24/05/29 14:12:51 WARN DAGScheduler: Broadcasting large task binary with size 1815.5 KiB
# 24/05/29 14:12:52 WARN DAGScheduler: Broadcasting large task binary with size 1816.0 KiB
# 24/05/29 14:12:52 WARN DAGScheduler: Broadcasting large task binary with size 1816.6 KiB
# 24/05/29 14:12:52 WARN DAGScheduler: Broadcasting large task binary with size 1817.8 KiB
# 24/05/29 14:12:52 WARN DAGScheduler: Broadcasting large task binary with size 1820.2 KiB
# 24/05/29 14:12:52 WARN DAGScheduler: Broadcasting large task binary with size 1824.8 KiB
# 24/05/29 14:12:52 WARN DAGScheduler: Broadcasting large task binary with size 1833.5 KiB
# 24/05/29 14:12:52 WARN DAGScheduler: Broadcasting large task binary with size 1850.3 KiB
# 24/05/29 14:12:52 WARN DAGScheduler: Broadcasting large task binary with size 1878.5 KiB
# 24/05/29 14:12:53 WARN DAGScheduler: Broadcasting large task binary with size 1926.7 KiB
# 24/05/29 14:12:53 WARN DAGScheduler: Broadcasting large task binary with size 1925.1 KiB
# 24/05/29 14:12:53 WARN DAGScheduler: Broadcasting large task binary with size 1925.6 KiB
# 24/05/29 14:12:53 WARN DAGScheduler: Broadcasting large task binary with size 1926.2 KiB
# 24/05/29 14:12:53 WARN DAGScheduler: Broadcasting large task binary with size 1927.3 KiB
# 24/05/29 14:12:53 WARN DAGScheduler: Broadcasting large task binary with size 1929.8 KiB
# 24/05/29 14:12:53 WARN DAGScheduler: Broadcasting large task binary with size 1934.3 KiB
# 24/05/29 14:12:53 WARN DAGScheduler: Broadcasting large task binary with size 1943.1 KiB
# 24/05/29 14:12:54 WARN DAGScheduler: Broadcasting large task binary with size 1960.2 KiB
# 24/05/29 14:12:54 WARN DAGScheduler: Broadcasting large task binary with size 1989.1 KiB
# 24/05/29 14:12:54 WARN DAGScheduler: Broadcasting large task binary with size 2038.8 KiB
# 24/05/29 14:12:54 WARN DAGScheduler: Broadcasting large task binary with size 2038.0 KiB
# 24/05/29 14:12:54 WARN DAGScheduler: Broadcasting large task binary with size 2038.4 KiB
# 24/05/29 14:12:54 WARN DAGScheduler: Broadcasting large task binary with size 2039.1 KiB
# 24/05/29 14:12:55 WARN DAGScheduler: Broadcasting large task binary with size 2040.2 KiB
# 24/05/29 14:12:55 WARN DAGScheduler: Broadcasting large task binary with size 2042.7 KiB
# 24/05/29 14:12:55 WARN DAGScheduler: Broadcasting large task binary with size 2047.2 KiB
# 24/05/29 14:12:55 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 24/05/29 14:12:55 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 24/05/29 14:12:55 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:12:55 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:12:56 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:12:56 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:12:56 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:12:56 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:12:56 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:12:56 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:12:57 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:12:57 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 24/05/29 14:12:57 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 24/05/29 14:12:57 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 24/05/29 14:13:07 WARN DAGScheduler: Broadcasting large task binary with size 1038.7 KiB
# 24/05/29 14:13:07 WARN DAGScheduler: Broadcasting large task binary with size 1036.7 KiB
# 24/05/29 14:13:07 WARN DAGScheduler: Broadcasting large task binary with size 1037.2 KiB
# 24/05/29 14:13:07 WARN DAGScheduler: Broadcasting large task binary with size 1037.8 KiB
# 24/05/29 14:13:07 WARN DAGScheduler: Broadcasting large task binary with size 1038.9 KiB
# 24/05/29 14:13:07 WARN DAGScheduler: Broadcasting large task binary with size 1040.9 KiB
# 24/05/29 14:13:07 WARN DAGScheduler: Broadcasting large task binary with size 1045.0 KiB
# 24/05/29 14:13:08 WARN DAGScheduler: Broadcasting large task binary with size 1052.8 KiB
# 24/05/29 14:13:08 WARN DAGScheduler: Broadcasting large task binary with size 1066.8 KiB
# 24/05/29 14:13:08 WARN DAGScheduler: Broadcasting large task binary with size 1090.8 KiB
# 24/05/29 14:13:08 WARN DAGScheduler: Broadcasting large task binary with size 1132.2 KiB
# 24/05/29 14:13:08 WARN DAGScheduler: Broadcasting large task binary with size 1129.6 KiB
# 24/05/29 14:13:08 WARN DAGScheduler: Broadcasting large task binary with size 1130.1 KiB
# 24/05/29 14:13:08 WARN DAGScheduler: Broadcasting large task binary with size 1130.7 KiB
# 24/05/29 14:13:08 WARN DAGScheduler: Broadcasting large task binary with size 1131.8 KiB
# 24/05/29 14:13:09 WARN DAGScheduler: Broadcasting large task binary with size 1133.9 KiB
# 24/05/29 14:13:09 WARN DAGScheduler: Broadcasting large task binary with size 1137.9 KiB
# 24/05/29 14:13:09 WARN DAGScheduler: Broadcasting large task binary with size 1145.8 KiB
# 24/05/29 14:13:09 WARN DAGScheduler: Broadcasting large task binary with size 1160.0 KiB
# 24/05/29 14:13:09 WARN DAGScheduler: Broadcasting large task binary with size 1184.1 KiB
# 24/05/29 14:13:09 WARN DAGScheduler: Broadcasting large task binary with size 1225.6 KiB
# 24/05/29 14:13:09 WARN DAGScheduler: Broadcasting large task binary with size 1222.2 KiB
# 24/05/29 14:13:09 WARN DAGScheduler: Broadcasting large task binary with size 1222.7 KiB
# 24/05/29 14:13:10 WARN DAGScheduler: Broadcasting large task binary with size 1223.3 KiB
# 24/05/29 14:13:10 WARN DAGScheduler: Broadcasting large task binary with size 1224.4 KiB
# 24/05/29 14:13:10 WARN DAGScheduler: Broadcasting large task binary with size 1226.4 KiB
# 24/05/29 14:13:10 WARN DAGScheduler: Broadcasting large task binary with size 1230.5 KiB
# 24/05/29 14:13:10 WARN DAGScheduler: Broadcasting large task binary with size 1238.3 KiB
# 24/05/29 14:13:10 WARN DAGScheduler: Broadcasting large task binary with size 1252.3 KiB
# 24/05/29 14:13:10 WARN DAGScheduler: Broadcasting large task binary with size 1276.5 KiB
# 24/05/29 14:13:10 WARN DAGScheduler: Broadcasting large task binary with size 1316.4 KiB
# 24/05/29 14:13:10 WARN DAGScheduler: Broadcasting large task binary with size 1314.7 KiB
# 24/05/29 14:13:11 WARN DAGScheduler: Broadcasting large task binary with size 1315.2 KiB
# 24/05/29 14:13:11 WARN DAGScheduler: Broadcasting large task binary with size 1315.8 KiB
# 24/05/29 14:13:11 WARN DAGScheduler: Broadcasting large task binary with size 1316.9 KiB
# 24/05/29 14:13:11 WARN DAGScheduler: Broadcasting large task binary with size 1319.0 KiB
# 24/05/29 14:13:11 WARN DAGScheduler: Broadcasting large task binary with size 1322.9 KiB
# 24/05/29 14:13:11 WARN DAGScheduler: Broadcasting large task binary with size 1330.9 KiB
# 24/05/29 14:13:11 WARN DAGScheduler: Broadcasting large task binary with size 1345.0 KiB
# 24/05/29 14:13:11 WARN DAGScheduler: Broadcasting large task binary with size 1368.5 KiB
# 24/05/29 14:13:12 WARN DAGScheduler: Broadcasting large task binary with size 1407.9 KiB
# 24/05/29 14:13:12 WARN DAGScheduler: Broadcasting large task binary with size 1406.1 KiB
# 24/05/29 14:13:12 WARN DAGScheduler: Broadcasting large task binary with size 1406.6 KiB
# 24/05/29 14:13:12 WARN DAGScheduler: Broadcasting large task binary with size 1407.2 KiB
# 24/05/29 14:13:12 WARN DAGScheduler: Broadcasting large task binary with size 1408.4 KiB
# 24/05/29 14:13:12 WARN DAGScheduler: Broadcasting large task binary with size 1410.7 KiB
# 24/05/29 14:13:12 WARN DAGScheduler: Broadcasting large task binary with size 1415.3 KiB
# 24/05/29 14:13:13 WARN DAGScheduler: Broadcasting large task binary with size 1423.3 KiB
# 24/05/29 14:13:13 WARN DAGScheduler: Broadcasting large task binary with size 1437.1 KiB
# 24/05/29 14:13:13 WARN DAGScheduler: Broadcasting large task binary with size 1460.7 KiB
# 24/05/29 14:13:13 WARN DAGScheduler: Broadcasting large task binary with size 1500.8 KiB
# 24/05/29 14:13:13 WARN DAGScheduler: Broadcasting large task binary with size 1497.2 KiB
# 24/05/29 14:13:13 WARN DAGScheduler: Broadcasting large task binary with size 1497.7 KiB
# 24/05/29 14:13:13 WARN DAGScheduler: Broadcasting large task binary with size 1498.3 KiB
# 24/05/29 14:13:14 WARN DAGScheduler: Broadcasting large task binary with size 1499.4 KiB
# 24/05/29 14:13:14 WARN DAGScheduler: Broadcasting large task binary with size 1501.5 KiB
# 24/05/29 14:13:14 WARN DAGScheduler: Broadcasting large task binary with size 1505.4 KiB
# 24/05/29 14:13:14 WARN DAGScheduler: Broadcasting large task binary with size 1513.3 KiB
# 24/05/29 14:13:14 WARN DAGScheduler: Broadcasting large task binary with size 1527.3 KiB
# 24/05/29 14:13:14 WARN DAGScheduler: Broadcasting large task binary with size 1550.6 KiB
# 24/05/29 14:13:14 WARN DAGScheduler: Broadcasting large task binary with size 1590.5 KiB
# 24/05/29 14:13:15 WARN DAGScheduler: Broadcasting large task binary with size 1588.5 KiB
# 24/05/29 14:13:15 WARN DAGScheduler: Broadcasting large task binary with size 1588.9 KiB
# 24/05/29 14:13:15 WARN DAGScheduler: Broadcasting large task binary with size 1589.5 KiB
# 24/05/29 14:13:15 WARN DAGScheduler: Broadcasting large task binary with size 1590.7 KiB
# 24/05/29 14:13:15 WARN DAGScheduler: Broadcasting large task binary with size 1592.7 KiB
# 24/05/29 14:13:15 WARN DAGScheduler: Broadcasting large task binary with size 1596.7 KiB
# 24/05/29 14:13:15 WARN DAGScheduler: Broadcasting large task binary with size 1604.6 KiB
# 24/05/29 14:13:15 WARN DAGScheduler: Broadcasting large task binary with size 1618.8 KiB
# 24/05/29 14:13:16 WARN DAGScheduler: Broadcasting large task binary with size 1642.3 KiB
# 24/05/29 14:13:16 WARN DAGScheduler: Broadcasting large task binary with size 1682.1 KiB
# 24/05/29 14:13:16 WARN DAGScheduler: Broadcasting large task binary with size 1679.4 KiB
# 24/05/29 14:13:16 WARN DAGScheduler: Broadcasting large task binary with size 1679.9 KiB
# 24/05/29 14:13:16 WARN DAGScheduler: Broadcasting large task binary with size 1680.4 KiB
# 24/05/29 14:13:16 WARN DAGScheduler: Broadcasting large task binary with size 1681.6 KiB
# 24/05/29 14:13:17 WARN DAGScheduler: Broadcasting large task binary with size 1683.6 KiB
# 24/05/29 14:13:17 WARN DAGScheduler: Broadcasting large task binary with size 1687.6 KiB
# 24/05/29 14:13:17 WARN DAGScheduler: Broadcasting large task binary with size 1695.5 KiB
# 24/05/29 14:13:17 WARN DAGScheduler: Broadcasting large task binary with size 1709.7 KiB
# 24/05/29 14:13:17 WARN DAGScheduler: Broadcasting large task binary with size 1733.8 KiB
# 24/05/29 14:13:17 WARN DAGScheduler: Broadcasting large task binary with size 1773.4 KiB
# 24/05/29 14:13:17 WARN DAGScheduler: Broadcasting large task binary with size 1770.7 KiB
# ...
# 24/05/29 14:16:20 WARN DAGScheduler: Broadcasting large task binary with size 1172.9 KiB
# 24/05/29 14:16:20 WARN DAGScheduler: Broadcasting large task binary with size 1171.9 KiB
# 24/05/29 14:16:20 WARN DAGScheduler: Broadcasting large task binary with size 1172.3 KiB
# 24/05/29 14:16:20 WARN DAGScheduler: Broadcasting large task binary with size 1172.9 KiB
# 24/05/29 14:16:20 WARN DAGScheduler: Broadcasting large task binary with size 1174.1 KiB
# 24/05/29 14:16:20 WARN DAGScheduler: Broadcasting large task binary with size 1176.2 KiB
# 24/05/29 14:16:20 WARN DAGScheduler: Broadcasting large task binary with size 1180.0 KiB
# 24/05/29 14:16:20 WARN DAGScheduler: Broadcasting large task binary with size 1187.8 KiB
# 24/05/29 14:16:21 WARN DAGScheduler: Broadcasting large task binary with size 1201.8 KiB
# 24/05/29 14:16:21 WARN DAGScheduler: Broadcasting large task binary with size 1224.7 KiB
# 24/05/29 14:16:21 WARN DAGScheduler: Broadcasting large task binary with size 1263.0 KiB
# 24/05/29 14:16:21 WARN DAGScheduler: Broadcasting large task binary with size 1262.4 KiB
# 24/05/29 14:16:21 WARN DAGScheduler: Broadcasting large task binary with size 1262.9 KiB
# 24/05/29 14:16:21 WARN DAGScheduler: Broadcasting large task binary with size 1263.4 KiB
# 24/05/29 14:16:21 WARN DAGScheduler: Broadcasting large task binary with size 1264.6 KiB
# 24/05/29 14:16:21 WARN DAGScheduler: Broadcasting large task binary with size 1267.0 KiB
# 24/05/29 14:16:21 WARN DAGScheduler: Broadcasting large task binary with size 1271.3 KiB
# 24/05/29 14:16:22 WARN DAGScheduler: Broadcasting large task binary with size 1278.7 KiB
# 24/05/29 14:16:22 WARN DAGScheduler: Broadcasting large task binary with size 1292.4 KiB
# 24/05/29 14:16:22 WARN DAGScheduler: Broadcasting large task binary with size 1315.0 KiB
# 24/05/29 14:16:22 WARN DAGScheduler: Broadcasting large task binary with size 1352.9 KiB
# 24/05/29 14:16:22 WARN DAGScheduler: Broadcasting large task binary with size 1350.8 KiB
# 24/05/29 14:16:22 WARN DAGScheduler: Broadcasting large task binary with size 1351.3 KiB
# 24/05/29 14:16:22 WARN DAGScheduler: Broadcasting large task binary with size 1351.9 KiB
# 24/05/29 14:16:23 WARN DAGScheduler: Broadcasting large task binary with size 1353.0 KiB
# 24/05/29 14:16:23 WARN DAGScheduler: Broadcasting large task binary with size 1355.4 KiB
# 24/05/29 14:16:23 WARN DAGScheduler: Broadcasting large task binary with size 1359.6 KiB
# 24/05/29 14:16:23 WARN DAGScheduler: Broadcasting large task binary with size 1367.5 KiB
# 24/05/29 14:16:23 WARN DAGScheduler: Broadcasting large task binary with size 1381.4 KiB
# 24/05/29 14:16:23 WARN DAGScheduler: Broadcasting large task binary with size 1404.0 KiB
# 24/05/29 14:16:23 WARN DAGScheduler: Broadcasting large task binary with size 1440.0 KiB
# 24/05/29 14:16:23 WARN DAGScheduler: Broadcasting large task binary with size 1439.2 KiB
# 24/05/29 14:16:24 WARN DAGScheduler: Broadcasting large task binary with size 1439.7 KiB
# 24/05/29 14:16:24 WARN DAGScheduler: Broadcasting large task binary with size 1440.3 KiB
# 24/05/29 14:16:24 WARN DAGScheduler: Broadcasting large task binary with size 1441.5 KiB
# 24/05/29 14:16:24 WARN DAGScheduler: Broadcasting large task binary with size 1443.8 KiB
# 24/05/29 14:16:24 WARN DAGScheduler: Broadcasting large task binary with size 1447.6 KiB
# 24/05/29 14:16:24 WARN DAGScheduler: Broadcasting large task binary with size 1454.6 KiB
# 24/05/29 14:16:24 WARN DAGScheduler: Broadcasting large task binary with size 1468.4 KiB
# 24/05/29 14:16:25 WARN DAGScheduler: Broadcasting large task binary with size 1491.1 KiB
# 24/05/29 14:16:25 WARN DAGScheduler: Broadcasting large task binary with size 1529.6 KiB
# 24/05/29 14:16:25 WARN DAGScheduler: Broadcasting large task binary with size 1527.8 KiB
# 24/05/29 14:16:25 WARN DAGScheduler: Broadcasting large task binary with size 1528.3 KiB
# 24/05/29 14:16:25 WARN DAGScheduler: Broadcasting large task binary with size 1528.9 KiB
# 24/05/29 14:16:25 WARN DAGScheduler: Broadcasting large task binary with size 1530.0 KiB
# 24/05/29 14:16:25 WARN DAGScheduler: Broadcasting large task binary with size 1532.0 KiB
# 24/05/29 14:16:26 WARN DAGScheduler: Broadcasting large task binary with size 1535.8 KiB
# 24/05/29 14:16:26 WARN DAGScheduler: Broadcasting large task binary with size 1542.8 KiB
# 24/05/29 14:16:26 WARN DAGScheduler: Broadcasting large task binary with size 1556.7 KiB
# 24/05/29 14:16:26 WARN DAGScheduler: Broadcasting large task binary with size 1579.8 KiB
# 24/05/29 14:16:27 WARN DAGScheduler: Broadcasting large task binary with size 1618.9 KiB
# 24/05/29 14:16:27 WARN DAGScheduler: Broadcasting large task binary with size 1617.2 KiB
# 24/05/29 14:16:27 WARN DAGScheduler: Broadcasting large task binary with size 1617.6 KiB
# 24/05/29 14:16:27 WARN DAGScheduler: Broadcasting large task binary with size 1618.2 KiB
# 24/05/29 14:16:27 WARN DAGScheduler: Broadcasting large task binary with size 1619.4 KiB
# 24/05/29 14:16:27 WARN DAGScheduler: Broadcasting large task binary with size 1621.4 KiB
# 24/05/29 14:16:27 WARN DAGScheduler: Broadcasting large task binary with size 1625.1 KiB
# 24/05/29 14:16:28 WARN DAGScheduler: Broadcasting large task binary with size 1632.3 KiB
# 24/05/29 14:16:28 WARN DAGScheduler: Broadcasting large task binary with size 1646.1 KiB
# 24/05/29 14:16:28 WARN DAGScheduler: Broadcasting large task binary with size 1670.0 KiB
# 24/05/29 14:16:28 WARN DAGScheduler: Broadcasting large task binary with size 1709.7 KiB
# 24/05/29 14:16:28 WARN DAGScheduler: Broadcasting large task binary with size 1708.7 KiB
# 24/05/29 14:16:28 WARN DAGScheduler: Broadcasting large task binary with size 1709.1 KiB
# 24/05/29 14:16:28 WARN DAGScheduler: Broadcasting large task binary with size 1709.7 KiB
# 24/05/29 14:16:29 WARN DAGScheduler: Broadcasting large task binary with size 1710.9 KiB
# 24/05/29 14:16:29 WARN DAGScheduler: Broadcasting large task binary with size 1712.9 KiB
# 24/05/29 14:16:29 WARN DAGScheduler: Broadcasting large task binary with size 1716.6 KiB
# 24/05/29 14:16:29 WARN DAGScheduler: Broadcasting large task binary with size 1723.9 KiB
# 24/05/29 14:16:29 WARN DAGScheduler: Broadcasting large task binary with size 1737.6 KiB
# 24/05/29 14:16:29 WARN DAGScheduler: Broadcasting large task binary with size 1761.0 KiB
# 24/05/29 14:16:29 WARN DAGScheduler: Broadcasting large task binary with size 1800.8 KiB
# 24/05/29 14:16:30 WARN DAGScheduler: Broadcasting large task binary with size 1799.1 KiB
# 24/05/29 14:16:30 WARN DAGScheduler: Broadcasting large task binary with size 1799.5 KiB
# 24/05/29 14:16:30 WARN DAGScheduler: Broadcasting large task binary with size 1800.1 KiB
# 24/05/29 14:16:30 WARN DAGScheduler: Broadcasting large task binary with size 1801.3 KiB
# 24/05/29 14:16:30 WARN DAGScheduler: Broadcasting large task binary with size 1803.3 KiB
# 24/05/29 14:16:30 WARN DAGScheduler: Broadcasting large task binary with size 1807.0 KiB
# 24/05/29 14:16:30 WARN DAGScheduler: Broadcasting large task binary with size 1814.2 KiB
# 24/05/29 14:16:31 WARN DAGScheduler: Broadcasting large task binary with size 1826.9 KiB
# 24/05/29 14:16:31 WARN DAGScheduler: Broadcasting large task binary with size 1848.9 KiB
# 24/05/29 14:16:31 WARN DAGScheduler: Broadcasting large task binary with size 1886.8 KiB
# 24/05/29 14:16:43 WARN DAGScheduler: Broadcasting large task binary with size 1008.1 KiB
# 24/05/29 14:16:43 WARN DAGScheduler: Broadcasting large task binary with size 1026.1 KiB
# 24/05/29 14:16:44 WARN DAGScheduler: Broadcasting large task binary with size 1055.3 KiB
# 24/05/29 14:16:44 WARN DAGScheduler: Broadcasting large task binary with size 1050.3 KiB
# 24/05/29 14:16:44 WARN DAGScheduler: Broadcasting large task binary with size 1050.8 KiB
# 24/05/29 14:16:44 WARN DAGScheduler: Broadcasting large task binary with size 1051.4 KiB
# 24/05/29 14:16:44 WARN DAGScheduler: Broadcasting large task binary with size 1052.5 KiB
# 24/05/29 14:16:44 WARN DAGScheduler: Broadcasting large task binary with size 1054.5 KiB
# 24/05/29 14:16:44 WARN DAGScheduler: Broadcasting large task binary with size 1058.2 KiB
# 24/05/29 14:16:44 WARN DAGScheduler: Broadcasting large task binary with size 1064.7 KiB
# 24/05/29 14:16:44 WARN DAGScheduler: Broadcasting large task binary with size 1076.4 KiB
# 24/05/29 14:16:45 WARN DAGScheduler: Broadcasting large task binary with size 1095.3 KiB
# 24/05/29 14:16:45 WARN DAGScheduler: Broadcasting large task binary with size 1126.1 KiB
# 24/05/29 14:16:45 WARN DAGScheduler: Broadcasting large task binary with size 1124.2 KiB
# 24/05/29 14:16:45 WARN DAGScheduler: Broadcasting large task binary with size 1124.7 KiB
# 24/05/29 14:16:45 WARN DAGScheduler: Broadcasting large task binary with size 1125.3 KiB
# 24/05/29 14:16:45 WARN DAGScheduler: Broadcasting large task binary with size 1126.4 KiB
# 24/05/29 14:16:45 WARN DAGScheduler: Broadcasting large task binary with size 1128.4 KiB
# 24/05/29 14:16:45 WARN DAGScheduler: Broadcasting large task binary with size 1132.1 KiB
# 24/05/29 14:16:46 WARN DAGScheduler: Broadcasting large task binary with size 1138.7 KiB
# 24/05/29 14:16:46 WARN DAGScheduler: Broadcasting large task binary with size 1150.4 KiB
# 24/05/29 14:16:46 WARN DAGScheduler: Broadcasting large task binary with size 1169.1 KiB
# 24/05/29 14:16:46 WARN DAGScheduler: Broadcasting large task binary with size 1199.2 KiB
# 24/05/29 14:16:46 WARN DAGScheduler: Broadcasting large task binary with size 1197.0 KiB
# 24/05/29 14:16:46 WARN DAGScheduler: Broadcasting large task binary with size 1197.4 KiB
# 24/05/29 14:16:47 WARN DAGScheduler: Broadcasting large task binary with size 1198.1 KiB
# 24/05/29 14:16:47 WARN DAGScheduler: Broadcasting large task binary with size 1199.2 KiB
# 24/05/29 14:16:47 WARN DAGScheduler: Broadcasting large task binary with size 1201.2 KiB
# 24/05/29 14:16:47 WARN DAGScheduler: Broadcasting large task binary with size 1204.8 KiB
# 24/05/29 14:16:47 WARN DAGScheduler: Broadcasting large task binary with size 1211.1 KiB
# 24/05/29 14:16:47 WARN DAGScheduler: Broadcasting large task binary with size 1222.9 KiB
# 24/05/29 14:16:47 WARN DAGScheduler: Broadcasting large task binary with size 1242.6 KiB
# 24/05/29 14:16:47 WARN DAGScheduler: Broadcasting large task binary with size 1275.8 KiB
# 24/05/29 14:16:48 WARN DAGScheduler: Broadcasting large task binary with size 1273.7 KiB
# 24/05/29 14:16:48 WARN DAGScheduler: Broadcasting large task binary with size 1274.2 KiB
# 24/05/29 14:16:48 WARN DAGScheduler: Broadcasting large task binary with size 1274.8 KiB
# 24/05/29 14:16:48 WARN DAGScheduler: Broadcasting large task binary with size 1275.9 KiB
# 24/05/29 14:16:48 WARN DAGScheduler: Broadcasting large task binary with size 1278.1 KiB
# 24/05/29 14:16:48 WARN DAGScheduler: Broadcasting large task binary with size 1282.4 KiB
# 24/05/29 14:16:48 WARN DAGScheduler: Broadcasting large task binary with size 1290.0 KiB
# 24/05/29 14:16:48 WARN DAGScheduler: Broadcasting large task binary with size 1304.1 KiB
# 24/05/29 14:16:49 WARN DAGScheduler: Broadcasting large task binary with size 1327.6 KiB
# 24/05/29 14:16:49 WARN DAGScheduler: Broadcasting large task binary with size 1362.6 KiB
# 24/05/29 14:16:49 WARN DAGScheduler: Broadcasting large task binary with size 1356.0 KiB
# 24/05/29 14:16:49 WARN DAGScheduler: Broadcasting large task binary with size 1356.6 KiB
# 24/05/29 14:16:49 WARN DAGScheduler: Broadcasting large task binary with size 1357.2 KiB
# 24/05/29 14:16:49 WARN DAGScheduler: Broadcasting large task binary with size 1358.3 KiB
# 24/05/29 14:16:49 WARN DAGScheduler: Broadcasting large task binary with size 1360.6 KiB
# 24/05/29 14:16:49 WARN DAGScheduler: Broadcasting large task binary with size 1365.1 KiB
# 24/05/29 14:16:50 WARN DAGScheduler: Broadcasting large task binary with size 1373.5 KiB
# 24/05/29 14:16:50 WARN DAGScheduler: Broadcasting large task binary with size 1388.6 KiB
# 24/05/29 14:16:50 WARN DAGScheduler: Broadcasting large task binary with size 1411.4 KiB
# 24/05/29 14:16:50 WARN DAGScheduler: Broadcasting large task binary with size 1446.1 KiB
# 24/05/29 14:16:50 WARN DAGScheduler: Broadcasting large task binary with size 1437.7 KiB
# 24/05/29 14:16:50 WARN DAGScheduler: Broadcasting large task binary with size 1438.3 KiB
# 24/05/29 14:16:50 WARN DAGScheduler: Broadcasting large task binary with size 1438.8 KiB
# 24/05/29 14:16:50 WARN DAGScheduler: Broadcasting large task binary with size 1440.0 KiB
# 24/05/29 14:16:51 WARN DAGScheduler: Broadcasting large task binary with size 1442.3 KiB
# 24/05/29 14:16:51 WARN DAGScheduler: Broadcasting large task binary with size 1446.8 KiB
# 24/05/29 14:16:51 WARN DAGScheduler: Broadcasting large task binary with size 1455.2 KiB
# 24/05/29 14:16:51 WARN DAGScheduler: Broadcasting large task binary with size 1470.1 KiB
# 24/05/29 14:16:51 WARN DAGScheduler: Broadcasting large task binary with size 1493.2 KiB
# 24/05/29 14:16:51 WARN DAGScheduler: Broadcasting large task binary with size 1527.5 KiB
# 24/05/29 14:17:07 WARN DAGScheduler: Broadcasting large task binary with size 1006.4 KiB
# 24/05/29 14:17:07 WARN DAGScheduler: Broadcasting large task binary with size 1019.7 KiB
# 24/05/29 14:17:07 WARN DAGScheduler: Broadcasting large task binary with size 1042.8 KiB
# 24/05/29 14:17:07 WARN DAGScheduler: Broadcasting large task binary with size 1041.1 KiB
# 24/05/29 14:17:07 WARN DAGScheduler: Broadcasting large task binary with size 1041.6 KiB
# 24/05/29 14:17:07 WARN DAGScheduler: Broadcasting large task binary with size 1042.2 KiB
# 24/05/29 14:17:07 WARN DAGScheduler: Broadcasting large task binary with size 1043.4 KiB
# 24/05/29 14:17:07 WARN DAGScheduler: Broadcasting large task binary with size 1045.4 KiB
# 24/05/29 14:17:08 WARN DAGScheduler: Broadcasting large task binary with size 1048.4 KiB
# 24/05/29 14:17:08 WARN DAGScheduler: Broadcasting large task binary with size 1053.5 KiB
# 24/05/29 14:17:08 WARN DAGScheduler: Broadcasting large task binary with size 1062.4 KiB
# 24/05/29 14:17:08 WARN DAGScheduler: Broadcasting large task binary with size 1075.6 KiB
# 24/05/29 14:17:08 WARN DAGScheduler: Broadcasting large task binary with size 1097.2 KiB
# 24/05/29 14:17:08 WARN DAGScheduler: Broadcasting large task binary with size 1096.4 KiB
# 24/05/29 14:17:08 WARN DAGScheduler: Broadcasting large task binary with size 1097.0 KiB
# 24/05/29 14:17:08 WARN DAGScheduler: Broadcasting large task binary with size 1097.5 KiB
# 24/05/29 14:17:08 WARN DAGScheduler: Broadcasting large task binary with size 1098.7 KiB
# 24/05/29 14:17:09 WARN DAGScheduler: Broadcasting large task binary with size 1100.7 KiB
# 24/05/29 14:17:09 WARN DAGScheduler: Broadcasting large task binary with size 1103.7 KiB
# 24/05/29 14:17:09 WARN DAGScheduler: Broadcasting large task binary with size 1108.8 KiB
# 24/05/29 14:17:09 WARN DAGScheduler: Broadcasting large task binary with size 1117.5 KiB
# 24/05/29 14:17:09 WARN DAGScheduler: Broadcasting large task binary with size 1131.0 KiB
# 24/05/29 14:17:09 WARN DAGScheduler: Broadcasting large task binary with size 1152.6 KiB
# 24/05/29 14:17:09 WARN DAGScheduler: Broadcasting large task binary with size 1150.7 KiB
# 24/05/29 14:17:09 WARN DAGScheduler: Broadcasting large task binary with size 1151.3 KiB
# 24/05/29 14:17:09 WARN DAGScheduler: Broadcasting large task binary with size 1151.8 KiB
# 24/05/29 14:17:10 WARN DAGScheduler: Broadcasting large task binary with size 1153.0 KiB
# 24/05/29 14:17:10 WARN DAGScheduler: Broadcasting large task binary with size 1155.3 KiB
# 24/05/29 14:17:10 WARN DAGScheduler: Broadcasting large task binary with size 1158.6 KiB
# 24/05/29 14:17:10 WARN DAGScheduler: Broadcasting large task binary with size 1163.6 KiB
# 24/05/29 14:17:10 WARN DAGScheduler: Broadcasting large task binary with size 1172.6 KiB
# 24/05/29 14:17:10 WARN DAGScheduler: Broadcasting large task binary with size 1185.4 KiB
# 24/05/29 14:17:10 WARN DAGScheduler: Broadcasting large task binary with size 1205.8 KiB
# 24/05/29 14:17:12 WARN DAGScheduler: Broadcasting large task binary with size 6.3 MiB
# [Stage 12081:===========================>                           (1 + 1) / 2]
# GBTClassifier Accuracy = 0.72

# %% [markdown]
# 4. Support Vector Machine

# %%
svm = LinearSVC(labelCol="immatriculation_ext_categorie_index", featuresCol="features")
ovr = OneVsRest(classifier=svm, labelCol="immatriculation_ext_categorie_index", featuresCol="features")

svm_param_grid = ParamGridBuilder()\
    .addGrid(svm.maxIter, [10, 20])\
    .addGrid(svm.regParam, [0.01, 0.1])\
    .build()

svm_model, svm_accuracy = evaluate_classifier(
    classifier=ovr,
    param_grid=svm_param_grid,
    train_df=train_df,
    test_df=test_df
)

print("LinearSVC Accuracy = {:.2f}".format(svm_accuracy))
# Out:
# [Stage 14376:===========================>                           (1 + 1) / 2]
# LinearSVC Accuracy = 0.63

# %% [markdown]
# 5. Logistic Regression

# %%
lr = LogisticRegression(labelCol="immatriculation_ext_categorie_index", featuresCol="features")

lr_param_grid = ParamGridBuilder()\
    .addGrid(lr.maxIter, [10, 20])\
    .addGrid(lr.regParam, [0.01, 0.1])\
    .addGrid(lr.elasticNetParam, [0.0, 0.5, 1.0])\
    .build()

lr_model, lr_accuracy = evaluate_classifier(
    classifier=lr,
    param_grid=lr_param_grid,
    train_df=train_df,
    test_df=test_df
)

print("LogisticRegression Accuracy = {:.2f}".format(lr_accuracy))
# Out:
# LogisticRegression Accuracy = 0.65

# %% [markdown]
# 6. Neural Networks (Multilayer Perceptron Classifier)

# %%
num_classes = train_df.select("immatriculation_ext_categorie_index").distinct().count()

mlp = MultilayerPerceptronClassifier(labelCol="immatriculation_ext_categorie_index", featuresCol="features", layers=[6, 5, 4, num_classes])

mlp_param_grid = ParamGridBuilder()\
    .addGrid(mlp.maxIter, [50, 100])\
    .build()

mlp_model, mlp_accuracy = evaluate_classifier(
    classifier=mlp,
    param_grid=mlp_param_grid,
    train_df=train_df,
    test_df=test_df
)

print("MultilayerPerceptronClassifier Accuracy = {:.2f}".format(mlp_accuracy))
# Out:
# 24/05/29 14:26:09 ERROR LBFGS: Failure! Resetting history: breeze.optimize.FirstOrderException: Line search zoom failed
# 24/05/29 14:26:10 ERROR LBFGS: Failure! Resetting history: breeze.optimize.FirstOrderException: Line search failed
# MultilayerPerceptronClassifier Accuracy = 0.56

# %% [markdown]
# 7. Naive Bayes

# %%
nb = NaiveBayes(labelCol="immatriculation_ext_categorie_index", featuresCol="features")

nb_param_grid = ParamGridBuilder()\
    .addGrid(nb.smoothing, [0.5, 1.0, 1.5])\
    .build()

nb_model, nb_accuracy = evaluate_classifier(
    classifier=nb,
    param_grid=nb_param_grid,
    train_df=train_df,
    test_df=test_df
)

print("NaiveBayes Accuracy = {:.2f}".format(nb_accuracy))
# Out:
# NaiveBayes Accuracy = 0.46
